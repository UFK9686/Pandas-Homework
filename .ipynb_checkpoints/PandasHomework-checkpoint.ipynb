# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns = pd.read_csv("whale_returns.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_returns.sort_index(ascending = True, inplace = True)
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull()
whale_returns.isnull().mean()
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna()
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns= pd.read_csv("algo_returns.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_returns.sort_index(ascending = True, inplace = True)
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns.isnull()
algo_returns.isnull().mean()
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns = algo_returns.dropna()
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500 = pd.read_csv("sp500_history.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500.sort_index(ascending = True, inplace = True)
#Remove dollar sign in "Close" column
sp500["Close"] = sp500["Close"].str.replace("$", "")
sp500.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Check Data Types
sp500.dtypes
# Out:
# Close    object
# dtype: object

# %%
whale_returns.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
algo_returns.dtypes
# Out:
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
# Fix Data Types
sp500["Close"] = sp500["Close"].astype("float")
sp500.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
daily_returns = sp500["Close"].pct_change()
daily_returns.head()
# Out:
# Date
# 2012-10-01         NaN
# 2012-10-02    0.000872
# 2012-10-03    0.003624
# 2012-10-04    0.007174
# 2012-10-05   -0.000322
# Name: Close, dtype: float64

# %%
# Drop nulls
daily_returns = daily_returns.dropna()
daily_returns.isnull().sum()
daily_returns.head()
# Out:
# Date
# 2012-10-02    0.000872
# 2012-10-03    0.003624
# 2012-10-04    0.007174
# 2012-10-05   -0.000322
# 2012-10-08   -0.003457
# Name: Close, dtype: float64

# %%
sp500["Daily_Returns"] = sp500["Close"].pct_change()
sp500 = sp500.drop(columns=["Close"])
sp500.head()
# Out:
#             Daily_Returns
# Date
# 2012-10-01            NaN
# 2012-10-02       0.000872
# 2012-10-03       0.003624
# 2012-10-04       0.007174
# 2012-10-05      -0.000322

# %%
#Created "daily returns" column and deleted "close" column in previous cell.
sp500.head()
# Out:
#             Daily_Returns
# Date
# 2012-10-01            NaN
# 2012-10-02       0.000872
# 2012-10-03       0.003624
# 2012-10-04       0.007174
# 2012-10-05      -0.000322

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
joined_data_rows = pd.concat([whale_returns, algo_returns, sp500], axis="columns", join="inner")
joined_data_rows = joined_data_rows.rename(columns={"Daily_Returns": "SP 500 Returns"})
joined_data_rows.sort_index(ascending = True, inplace = True)
joined_data_rows.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP 500 Returns
# Date
# 2015-03-03 -0.000949       -0.004539
# 2015-03-04  0.002416       -0.004389
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
joined_data_rows.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + joined_data_rows).cumprod() 
cumulative_returns.head()
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10))

#Algo 1 and Berkshire outperform the SP500
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
joined_data_rows.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
standard_deviation = joined_data_rows.std()
standard_deviation
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP 500 Returns                 0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %% [raw]
# ### Determine which portfolios are riskier than the S&P 500
#
# SP500 has a standard deviation of 0.008554. The only two with higer standard deviations are Berkshire Hathaway
# and Tiger Global Management LLC. Therefore, Tiger Global Management LLC and Berkshire Hathaway are both riskier
# than the SP500.

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = standard_deviation * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
std_rolling = joined_data_rows.rolling(window=21).std()
std_rolling.head(50)

# Plot the rolling standard deviation
joined_data_rows.rolling(window=21).std().plot(figsize=(14,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = joined_data_rows.corr()
correlation

# Display de correlation matrix
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = joined_data_rows['Algo 1'].cov(joined_data_rows['SP 500 Returns'])
covariance
# Calculate variance of S&P 500
variance = joined_data_rows['SP 500 Returns'].var()
variance
# Computing beta
Algo_1_beta = covariance / variance
Algo_1_beta
# Plot beta trend
rolling_covariance = joined_data_rows['Algo 1'].rolling(window=60).cov(joined_data_rows['SP 500 Returns'])
rolling_variance = joined_data_rows['SP 500 Returns'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of Algo 1')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of Algo 1'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
joined_data_rows.ewm(halflife=21).std().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe = (joined_data_rows.mean() * 252) / (joined_data_rows.std() * np.sqrt(252))
sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP 500 Returns                 0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe.plot(kind = "bar", title = "Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo 1 outperformed market and all whale portfolios, while algo 2 fell below market, but outperformed every whale except Berkshire.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data
Apple_MyPort = pd.read_csv("AAPLMyPort.csv", index_col='Date', parse_dates=True, infer_datetime_format=True)
Apple_MyPort.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  27.33
# 2015-01-05 16:00:00  26.56
# 2015-01-06 16:00:00  26.57
# 2015-01-07 16:00:00  26.94
# 2015-01-08 16:00:00  27.97

# %%
# Reading data from 2nd stock
Tsla_MyPort = pd.read_csv("TSLAMyPort.csv", index_col='Date', parse_dates=True, infer_datetime_format=True)
Tsla_MyPort.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  43.86
# 2015-01-05 16:00:00  42.02
# 2015-01-06 16:00:00  42.26
# 2015-01-07 16:00:00  42.19
# 2015-01-08 16:00:00  42.12

# %%
# Reading data from 3rd stock
Amazon_MyPort = pd.read_csv("AmazonMyPort.csv", index_col='Date', parse_dates=True, infer_datetime_format=True)
Amazon_MyPort.head()
# Out:
#                       Close
# Date
# 2015-01-02 16:00:00  308.52
# 2015-01-05 16:00:00  302.19
# 2015-01-06 16:00:00  295.29
# 2015-01-07 16:00:00  298.42
# 2015-01-08 16:00:00  300.46

# %%
# Reading data from 4th stock
JPM_MyPort = pd.read_csv("JPMMyPort.csv", index_col='Date', parse_dates=True, infer_datetime_format=True)
JPM_MyPort.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  62.49
# 2015-01-05 16:00:00  60.55
# 2015-01-06 16:00:00  58.98
# 2015-01-07 16:00:00  59.07
# 2015-01-08 16:00:00  60.39

# %%
# Combine all stocks in a single DataFrame 
# Reset Date index
# Reorganize portfolio data by having a column per symbol
Combined_MyPort = pd.concat([Apple_MyPort,Tsla_MyPort,Amazon_MyPort,JPM_MyPort], axis='columns', join='inner')
columns = ["Apple Close", "Tesla Close", "Amazon Close", "JPM Close"]
Combined_MyPort.columns = columns 
Combined_MyPort.sort_index(ascending=True, inplace=True)
Combined_MyPort.head()
# Out:
#                      Apple Close  Tesla Close  Amazon Close  JPM Close
# Date
# 2015-01-02 16:00:00        27.33        43.86        308.52      62.49
# 2015-01-05 16:00:00        26.56        42.02        302.19      60.55
# 2015-01-06 16:00:00        26.57        42.26        295.29      58.98
# 2015-01-07 16:00:00        26.94        42.19        298.42      59.07
# 2015-01-08 16:00:00        27.97        42.12        300.46      60.39

# %%
# Out:
#                      Apple Close  Tesla Close  Amazon Close  JPM Close
# Date
# 2015-01-02 16:00:00        27.33        43.86        308.52      62.49
# 2015-01-05 16:00:00        26.56        42.02        302.19      60.55
# 2015-01-06 16:00:00        26.57        42.26        295.29      58.98
# 2015-01-07 16:00:00        26.94        42.19        298.42      59.07
# 2015-01-08 16:00:00        27.97        42.12        300.46      60.39
# ...                          ...          ...           ...        ...
# 2019-07-24 16:00:00        52.17        52.98       2000.81     116.83
# 2019-07-25 16:00:00        51.76        45.76       1973.82     115.71
# 2019-07-26 16:00:00        51.94        45.61       1943.05     116.22
# 2019-07-29 16:00:00        52.42        47.15       1912.45     115.85
# 2019-07-30 16:00:00        52.20        48.45       1898.53     115.59
#
# [1151 rows x 4 columns]

# %%
# Calculate daily returns
Daily_returns = Combined_MyPort.pct_change()
Daily_returns
# Drop NAs
Daily_returns.dropna(inplace=True)
# Display sample data
Daily_returns.isnull().sum()
Daily_returns.tail()
# Out:
#                      Apple Close  Tesla Close  Amazon Close  JPM Close
# Date
# 2019-07-24 16:00:00    -0.000766     0.018259      0.003169   0.004039
# 2019-07-25 16:00:00    -0.007859    -0.136278     -0.013490  -0.009587
# 2019-07-26 16:00:00     0.003478    -0.003278     -0.015589   0.004408
# 2019-07-29 16:00:00     0.009241     0.033765     -0.015748  -0.003184
# 2019-07-30 16:00:00    -0.004197     0.027572     -0.007279  -0.002244

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [0.25, 0.25, 0.25, 0.25]

# Calculate portfolio return
portfolio_returns = Daily_returns.dot(weights)
portfolio_returns.head()
portfolio_returns.index = portfolio_returns.index.normalize()
portfolio_returns.dropna(inplace=True)
portfolio_returns.head()
# Display sample data
portfolio_returns.plot(figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
All_Portfolios = pd.concat([portfolio_returns,joined_data_rows], axis = "columns", join = "inner")
All_Portfolios.rename(columns = {0:"Umer Portfolio"}, inplace = True)
All_Portfolios
# Out:
#             Umer Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03        0.003458                  -0.001266           -0.004981
# 2015-03-04        0.001504                   0.002230            0.003241
# 2015-03-05       -0.003608                   0.004016            0.004076
# 2015-03-06       -0.017480                  -0.007905           -0.003574
# 2015-03-09       -0.001264                   0.000582            0.004225
# ...                    ...                        ...                 ...
# 2019-04-16        0.011622                   0.002699            0.000388
# 2019-04-17        0.010387                  -0.002897           -0.006467
# 2019-04-18        0.000522                   0.001448            0.001222
# 2019-04-22       -0.005073                  -0.002586           -0.007333
# 2019-04-23        0.009850                   0.007167            0.003485
#
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
All_Portfolios.dropna()
All_Portfolios
# Out:
#             Umer Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03        0.003458                  -0.001266           -0.004981
# 2015-03-04        0.001504                   0.002230            0.003241
# 2015-03-05       -0.003608                   0.004016            0.004076
# 2015-03-06       -0.017480                  -0.007905           -0.003574
# 2015-03-09       -0.001264                   0.000582            0.004225
# ...                    ...                        ...                 ...
# 2019-04-16        0.011622                   0.002699            0.000388
# 2019-04-17        0.010387                  -0.002897           -0.006467
# 2019-04-18        0.000522                   0.001448            0.001222
# 2019-04-22       -0.005073                  -0.002586           -0.007333
# 2019-04-23        0.009850                   0.007167            0.003485
#
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
#Daily Standard deviation
standard_deviation2 = All_Portfolios.std()
standard_deviation2
# Out:
# Umer Portfolio                 0.013636
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP 500 Returns                 0.008554
# dtype: float64

# %% [raw]
# *******My Portfolio is the riskiest, with the highest daily standard deviation.

# %%
# Calculate the annualized `std`
annualized_std2 = standard_deviation2 * np.sqrt(252)
annualized_std2
# Out:
# Umer Portfolio                 0.216465
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# SP 500 Returns                 0.135786
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
std_rolling2 = All_Portfolios.rolling(window=21).std()
std_rolling2.tail(50)

# Plot the rolling standard deviation
All_Portfolios.rolling(window=21).std().plot(figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation2 = All_Portfolios.corr()
correlation2

# Display de correlation matrix
sns.heatmap(correlation2, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta


# Calculate covariance of a single portfolio
covariance2 = All_Portfolios['Umer Portfolio'].cov(All_Portfolios['SP 500 Returns'])
covariance2
# Calculate variance of S&P 500
variance = All_Portfolios['SP 500 Returns'].var()
variance
# Computing beta
Umer_beta = covariance2 / variance
Umer_beta
# Plot beta trend
rolling_covariance2 = All_Portfolios['Umer Portfolio'].rolling(window=60).cov(All_Portfolios['SP 500 Returns'])
rolling_variance = All_Portfolios['SP 500 Returns'].rolling(window=60).var()
rolling_beta2 = rolling_covariance2 / rolling_variance
rolling_beta2.plot(figsize=(20, 10), title='Rolling 60-Day Beta of Umer Portfolio')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of Umer Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe2 = (All_Portfolios.mean() * 252) / (All_Portfolios.std() * np.sqrt(252))
sharpe2
# Out:
# Umer Portfolio                 1.058252
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP 500 Returns                 0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe2.plot(kind = "bar", title = "Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# My Portfolio performed excellent, only second to "Algo 1", overtaking Berkshire Hathaway for second best peformance, and significantly outperformed the SP500.
